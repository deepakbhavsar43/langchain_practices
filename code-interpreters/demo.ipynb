# %%
# %pip install codeinterpreterapi
# Out:
# Collecting codeinterpreterapi
#   Downloading codeinterpreterapi-0.1.17-py3-none-any.whl.metadata (6.9 kB)
# Collecting codeboxapi>=0.1.19 (from codeinterpreterapi)
#   Downloading codeboxapi-0.1.21-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-openai>=0.1.1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from codeinterpreterapi) (0.1.7)
# Requirement already satisfied: langchain>=0.1.14 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from codeinterpreterapi) (0.1.20)
# Collecting pyzmq==25.1.2 (from codeinterpreterapi)
#   Downloading pyzmq-25.1.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: aiohttp>=3.9 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from codeboxapi>=0.1.19->codeinterpreterapi) (3.9.5)
# Collecting pydantic-settings>=2 (from codeboxapi>=0.1.19->codeinterpreterapi)
#   Downloading pydantic_settings-2.3.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic>=2 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from codeboxapi>=0.1.19->codeinterpreterapi) (2.7.4)
# Requirement already satisfied: requests>=2 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from codeboxapi>=0.1.19->codeinterpreterapi) (2.32.3)
# Requirement already satisfied: websockets>=12 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from codeboxapi>=0.1.19->codeinterpreterapi) (12.0)
# Requirement already satisfied: PyYAML>=5.3 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain>=0.1.14->codeinterpreterapi) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain>=0.1.14->codeinterpreterapi) (2.0.31)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain>=0.1.14->codeinterpreterapi) (0.6.7)
# Requirement already satisfied: langchain-community<0.1,>=0.0.38 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain>=0.1.14->codeinterpreterapi) (0.0.38)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.52 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain>=0.1.14->codeinterpreterapi) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain>=0.1.14->codeinterpreterapi) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain>=0.1.14->codeinterpreterapi) (0.1.82)
# Requirement already satisfied: numpy<2,>=1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain>=0.1.14->codeinterpreterapi) (1.26.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain>=0.1.14->codeinterpreterapi) (8.4.2)
# Requirement already satisfied: openai<2.0.0,>=1.24.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-openai>=0.1.1->codeinterpreterapi) (1.35.3)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-openai>=0.1.1->codeinterpreterapi) (0.7.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9->codeboxapi>=0.1.19->codeinterpreterapi) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9->codeboxapi>=0.1.19->codeinterpreterapi) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9->codeboxapi>=0.1.19->codeinterpreterapi) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9->codeboxapi>=0.1.19->codeinterpreterapi) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp>=3.9->codeboxapi>=0.1.19->codeinterpreterapi) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.1.14->codeinterpreterapi) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.1.14->codeinterpreterapi) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain>=0.1.14->codeinterpreterapi) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain>=0.1.14->codeinterpreterapi) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain>=0.1.14->codeinterpreterapi) (3.10.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai>=0.1.1->codeinterpreterapi) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai>=0.1.1->codeinterpreterapi) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai>=0.1.1->codeinterpreterapi) (0.27.0)
# Requirement already satisfied: sniffio in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai>=0.1.1->codeinterpreterapi) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai>=0.1.1->codeinterpreterapi) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai>=0.1.1->codeinterpreterapi) (4.12.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic>=2->codeboxapi>=0.1.19->codeinterpreterapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic>=2->codeboxapi>=0.1.19->codeinterpreterapi) (2.18.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pydantic-settings>=2->codeboxapi>=0.1.19->codeinterpreterapi) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2->codeboxapi>=0.1.19->codeinterpreterapi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2->codeboxapi>=0.1.19->codeinterpreterapi) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2->codeboxapi>=0.1.19->codeinterpreterapi) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2->codeboxapi>=0.1.19->codeinterpreterapi) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain>=0.1.14->codeinterpreterapi) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai>=0.1.1->codeinterpreterapi) (2023.12.25)
# Requirement already satisfied: httpcore==1.* in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai>=0.1.1->codeinterpreterapi) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai>=0.1.1->codeinterpreterapi) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain>=0.1.14->codeinterpreterapi) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain>=0.1.14->codeinterpreterapi) (1.0.0)
# Downloading codeinterpreterapi-0.1.17-py3-none-any.whl (19 kB)
# Downloading pyzmq-25.1.2-cp311-cp311-manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 4.8 MB/s eta 0:00:0000:0100:01
# Downloading codeboxapi-0.1.21-py3-none-any.whl (14 kB)
# Downloading pydantic_settings-2.3.4-py3-none-any.whl (22 kB)
# Installing collected packages: pyzmq, pydantic-settings, codeboxapi, codeinterpreterapi
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 26.0.3
#     Uninstalling pyzmq-26.0.3:
#       Successfully uninstalled pyzmq-26.0.3
# Successfully installed codeboxapi-0.1.21 codeinterpreterapi-0.1.17 pydantic-settings-2.3.4 pyzmq-25.1.2
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
os.environ["VERBOSE"] = "True"

# %%
from codeinterpreterapi import CodeInterpreterSession

# %%
# %pip install jupyter-kernel-gateway
# Out:
# Collecting jupyter-kernel-gateway
#   Downloading jupyter_kernel_gateway-3.0.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter-client>=8.6 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-kernel-gateway) (8.6.2)
# Requirement already satisfied: jupyter-core>=5.7 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-kernel-gateway) (5.7.2)
# Collecting jupyter-server>=2.12 (from jupyter-kernel-gateway)
#   Downloading jupyter_server-2.14.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: requests>=2.31 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-kernel-gateway) (2.32.3)
# Requirement already satisfied: tornado>=6.4 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-kernel-gateway) (6.4.1)
# Requirement already satisfied: traitlets>=5.14.1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-kernel-gateway) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-client>=8.6->jupyter-kernel-gateway) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-client>=8.6->jupyter-kernel-gateway) (25.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-core>=5.7->jupyter-kernel-gateway) (4.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-server>=2.12->jupyter-kernel-gateway) (4.4.0)
# Collecting argon2-cffi>=21.1 (from jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jinja2>=3.0.3 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-server>=2.12->jupyter-kernel-gateway) (3.1.4)
# Collecting jupyter-events>=0.9.0 (from jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: overrides>=5.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-server>=2.12->jupyter-kernel-gateway) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-server>=2.12->jupyter-kernel-gateway) (23.2)
# Collecting prometheus-client>=0.9 (from jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-server>=2.12->jupyter-kernel-gateway) (1.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.31->jupyter-kernel-gateway) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.31->jupyter-kernel-gateway) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.31->jupyter-kernel-gateway) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.31->jupyter-kernel-gateway) (2024.6.2)
# Requirement already satisfied: sniffio>=1.1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server>=2.12->jupyter-kernel-gateway) (1.3.1)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyter-server>=2.12->jupyter-kernel-gateway) (2.1.5)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway) (4.22.0)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyyaml>=5.3 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway) (6.0.1)
# Requirement already satisfied: referencing in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway) (0.35.1)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: beautifulsoup4 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway) (4.12.3)
# Collecting bleach!=5.0.0 (from nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pygments>=2.4.1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway) (2.18.0)
# Collecting tinycss2 (from nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading tinycss2-1.3.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: six>=1.5 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.6->jupyter-kernel-gateway) (1.16.0)
# Requirement already satisfied: ptyprocess in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter-server>=2.12->jupyter-kernel-gateway) (0.7.0)
# Collecting webencodings (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: attrs>=22.2.0 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway) (0.18.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading webcolors-24.6.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.12->jupyter-kernel-gateway) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=2.12->jupyter-kernel-gateway) (2.5)
# Requirement already satisfied: pycparser in /home/vmuser/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2.12->jupyter-kernel-gateway) (2.22)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=2.12->jupyter-kernel-gateway)
#   Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl.metadata (1.8 kB)
# Downloading jupyter_kernel_gateway-3.0.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 1.9 MB/s eta 0:00:00
# Downloading jupyter_server-2.14.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.4/383.4 kB 3.1 MB/s eta 0:00:0000:0100:01
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading nbconvert-7.16.4-py3-none-any.whl (257 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.4/257.4 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 2.4 MB/s eta 0:00:00
# Downloading prometheus_client-0.20.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 1.9 MB/s eta 0:00:00
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.8/162.8 kB 5.4 MB/s eta 0:00:00
# Downloading fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 1.8 MB/s eta 0:00:00
# Downloading nbclient-0.10.0-py3-none-any.whl (25 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 3.3 MB/s eta 0:00:00
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading tinycss2-1.3.0-py3-none-any.whl (22 kB)
# Downloading webcolors-24.6.0-py3-none-any.whl (14 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.4 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20240316-py3-none-any.whl (9.7 kB)
# Installing collected packages: webencodings, fastjsonschema, webcolors, uri-template, types-python-dateutil, tinycss2, terminado, send2trash, rfc3986-validator, rfc3339-validator, python-json-logger, prometheus-client, pandocfilters, mistune, jupyterlab-pygments, fqdn, defusedxml, bleach, jupyter-server-terminals, arrow, argon2-cffi-bindings, isoduration, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, jupyter-kernel-gateway
# Successfully installed argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 bleach-6.1.0 defusedxml-0.7.1 fastjsonschema-2.20.0 fqdn-1.5.1 isoduration-20.11.0 jupyter-events-0.10.0 jupyter-kernel-gateway-3.0.1 jupyter-server-2.14.1 jupyter-server-terminals-0.5.3 jupyterlab-pygments-0.3.0 mistune-3.0.2 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 pandocfilters-1.5.1 prometheus-client-0.20.0 python-json-logger-2.0.7 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 terminado-0.18.1 tinycss2-1.3.0 types-python-dateutil-2.9.0.20240316 uri-template-1.3.0 webcolors-24.6.0 webencodings-0.5.1
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
with CodeInterpreterSession() as Session:
    response = Session.generate_response(
        """
            Plot the relative performance of tech giants (Apple, Google, Microsoft, Amazon) in 2023.
            
            Use a Normalized Plot so we can easily compare the percentage change of each stocks' price over the period.
        """
    )

    print("AI: ", response.content)

    for file in response.files:
        file.show_image()
# Out:
# INFO: Using a LocalBox which is not fully isolated
#       and not scalable across multiple users.
#       Make sure to use a CODEBOX_API_KEY in production.
#       Set envar SHOW_INFO=False to not see this again.
#
# Starting kernel...
# Waiting for kernel to start...
# Waiting for kernel to start...
# [I 2024-07-02 05:33:49.800 KernelGatewayApp] Writing Jupyter server cookie secret to /home/vmuser/.local/share/jupyter/runtime/jupyter_cookie_secret
# [I 2024-07-02 05:33:49.802 KernelGatewayApp] Jupyter Kernel Gateway 3.0.1 is available at http://0.0.0.0:8888
# [I 240702 05:33:50 web:2348] 200 GET /api (127.0.0.1) 1.86ms
# [I 2024-07-02 05:33:51.365 KernelGatewayApp] Kernel started: 10324133-0404-4d27-8a6a-7cb6e9e3a2d8
# [I 240702 05:33:51 web:2348] 201 POST /api/kernels (127.0.0.1) 728.05ms
# [W 2024-07-02 05:33:51.381 KernelGatewayApp] No session ID specified
# [I 240702 05:33:52 web:2348] 101 GET /api/kernels/10324133-0404-4d27-8a6a-7cb6e9e3a2d8/channels (127.0.0.1) 1033.94ms
# [I 2024-07-02 05:33:52.414 KernelGatewayApp] Connecting to kernel 10324133-0404-4d27-8a6a-7cb6e9e3a2d8.
# Running code:
#  !pip install -q
# Output:
#  ERROR: You must give at least one requirement to install (see "pip help install")
#
#
# Output:
#  ERROR: You must give at least one requirement to install (see "pip help install")
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
#
# Running code:
#  import matplotlib.pyplot as plt
# import yfinance as yf
#
# # Get stock data for Apple, Google, Microsoft, Amazon for 2023
# stocks = ['AAPL', 'GOOGL', 'MSFT', 'AMZN']
# stock_data = yf.download(stocks, start='2023-01-01', end='2023-12-31')['Adj Close']
#
# # Normalize the data to start at 100
# normalized_data = stock_data.div(stock_data.iloc[0]).mul(100)
#
# # Plot the normalized data
# plt.figure(figsize=(14, 7))
# for stock in normalized_data.columns:
#     plt.plot(normalized_data.index, normalized_data[stock], label=stock)
# plt.title('Relative Performance of Tech Giants in 2023')
# plt.xlabel('Date')
# plt.ylabel('Normalized Price (Starting at 100)')
# plt.legend()
# plt.grid(True)
# plt.show()
# Error:
#  ModuleNotFoundError: No module named 'matplotlib'
# Running code:
#  !pip install -q matplotlib
# Output:
#  [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
#
# Running code:
#  import matplotlib.pyplot as plt
# import yfinance as yf
#
# # Get stock data for Apple, Google, Microsoft, Amazon for 2023
# stocks = ['AAPL', 'GOOGL', 'MSFT', 'AMZN']
# stock_data = yf.download(stocks, start='2023-01-01', end='2023-12-31')['Adj Close']
#
# # Normalize the data to start at 100
# normalized_data = stock_data.div(stock_data.iloc[0]).mul(100)
#
# # Plot the normalized data
# plt.figure(figsize=(14, 7))
# for stock in normalized_data.columns:
#     plt.plot(normalized_data.index, normalized_data[stock], label=stock)
# plt.title('Relative Performance of Tech Giants in 2023')
# plt.xlabel('Date')
# plt.ylabel('Normalized Price (Starting at 100)')
# plt.legend()
# plt.grid(True)
# plt.show()
# Error:
#  ModuleNotFoundError: No module named 'yfinance'
# Running code:
#  !pip install -q yfinance
# Output:
#  [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
#
# Running code:
#  import matplotlib.pyplot as plt
# import yfinance as yf
#
# # Get stock data for Apple, Google, Microsoft, Amazon for 2023
# stocks = ['AAPL', 'GOOGL', 'MSFT', 'AMZN']
# stock_data = yf.download(stocks, start='2023-01-01', end='2023-12-31')['Adj Close']
#
# # Normalize the data to start at 100
# normalized_data = stock_data.div(stock_data.iloc[0]).mul(100)
#
# # Plot the normalized data
# plt.figure(figsize=(14, 7))
# for stock in normalized_data.columns:
#     plt.plot(normalized_data.index, normalized_data[stock], label=stock)
# plt.title('Relative Performance of Tech Giants in 2023')
# plt.xlabel('Date')
# plt.ylabel('Normalized Price (Starting at 100)')
# plt.legend()
# plt.grid(True)
# plt.show()
# Output:
#  [                       0%%                      ]
#
# Output:
#  [                       0%%                      ]
# [**********************50%%                      ]  2 of 4 completed
#
# Output:
#  [                       0%%                      ]
# [**********************50%%                      ]  2 of 4 completed
# [**********************50%%                      ]  2 of 4 completed
#
# Output:
#  [                       0%%                      ]
# [**********************50%%                      ]  2 of 4 completed
# [**********************50%%                      ]  2 of 4 completed
# [*********************100%%**********************]  4 of 4 completed
#
# Output:
#  [                       0%%                      ]
# [**********************50%%                      ]  2 of 4 completed
# [**********************50%%                      ]  2 of 4 completed
# [*********************100%%**********************]  4 of 4 completed
#
#
# AI:  The plot showing the relative performance of tech giants (Apple, Google, Microsoft, Amazon) in 2023, with normalized prices starting at 100, has been generated. You can see the image above for the visualization.
# <PIL.Image.Image image mode=RGB size=1160x624>
# [C 2024-07-02 05:35:24.343 KernelGatewayApp] received signal 15, stopping
# [I 2024-07-02 05:35:24.344 KernelGatewayApp] Kernel shutdown: 10324133-0404-4d27-8a6a-7cb6e9e3a2d8
